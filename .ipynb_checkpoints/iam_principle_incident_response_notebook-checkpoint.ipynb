# %% [markdown]
# # TDR254: Building incident response playbooks for AWS
#
# This notebook is to be used in case of malicious activity inside your AWS Account. We will query CloudTrail logs via Athena form within this notebook in order to discover and mitigate malicious account activity. We'll be following best practices from the Well-Architected Framework - Security Pillar as we go through our investigation and remediation efforts.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Load Libraries
#
# In order to query Athena and interact with AWS we need to load several libraries and configure our environment.

# %%
import boto3  # the Python SDK for AWS
import pandas as pd # Pandas is a data analysis tool for Python
import sys
pd.set_option("max_colwidth", 150) # Set maximum column width for outputs to make easier to read
# !{sys.executable} -m pip install PyAthena # This libary lets us query Athena from our notebook
region='us-east-1' #Set region variable to us-east-1 for commands
# Out:
# Requirement already satisfied: PyAthena in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.3.0)
# Requirement already satisfied: botocore>=1.5.52 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from PyAthena) (1.21.45)
# Requirement already satisfied: tenacity>=4.1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from PyAthena) (8.0.1)
# Requirement already satisfied: boto3>=1.4.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from PyAthena) (1.18.45)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.4.4->PyAthena) (0.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.4.4->PyAthena) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->PyAthena) (1.26.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore>=1.5.52->PyAthena) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.5.52->PyAthena) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Connect to Athena
#
# Next we'll setup a connection to our Athena endpoint.

# %%
from pyathena import connect
conn = connect(s3_staging_dir='s3://reinforce2021-tdr254-clo-athenaqueryresultsbucket-1inggpjk2pxo7',
   region_name='us-east-1')

# %% [markdown]
# ## Create Athena Tables
#
# In order to query our CloudTrail logs we need to create the tables in Athena.

# %%
create_table = """
CREATE EXTERNAL TABLE IF NOT EXISTS cloudtrail_logs (
   eventversion STRING,
   useridentity STRUCT<
                  type:STRING,
                  principalid:STRING,
                  arn:STRING,
                  accountid:STRING,
                  invokedby:STRING,
                  accesskeyid:STRING,
                  userName:STRING,
   sessioncontext:STRUCT<
   attributes:STRUCT<
                  mfaauthenticated:STRING,
                  creationdate:STRING>,
   sessionissuer:STRUCT<
                  type:STRING,
                  principalId:STRING,
                  arn:STRING, 
                  accountId:STRING,
                  userName:STRING>>>,
   eventtime STRING,
   eventsource STRING,
   eventname STRING,
   awsregion STRING,
   sourceipaddress STRING,
   useragent STRING,
   errorcode STRING,
   errormessage STRING,
   requestparameters STRING,
   responseelements STRING,
   additionaleventdata STRING,
   requestid STRING,
   eventid STRING,
   resources ARRAY<STRUCT<
                  ARN:STRING,
                  accountId:STRING,
                  type:STRING>>,
   eventtype STRING,
   apiversion STRING,
   readonly STRING,
   recipientaccountid STRING,
   serviceeventdetails STRING,
   sharedeventid STRING,
   vpcendpointid STRING
   )
ROW FORMAT SERDE 'com.amazon.emr.hive.serde.CloudTrailSerde'
STORED AS INPUTFORMAT 'com.amazon.emr.cloudtrail.CloudTrailInputFormat'
OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION 's3://reinforce2021-cloudtrail-jerchen-20211014/AWSLogs/910003606845/CloudTrail';"""
pd.read_sql(create_table, conn)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Investigate

# %% [markdown]
# ## Investigation 1
#
# In the first investigation you have been made aware of a potential security incident in your AWS account, some suspicious behaviour has been identified by a development team due to numerous failed access attempts to different resources. At this time they can’t provide you any more details so you’ll need to do your own investigations!

# %% [markdown]
# ### Step 1 - Discovery
# As you know there are some failed access attempts a good starting point is to see what failed access attempts we have in our Amazon CloudTrail logs, the sample SQL query is included here and is in your Jupyter notebook as well.

# %% [markdown]
# Check what are those failed user access activities.

# %%
query = """
select *
from cloudtrail_logs
where sourceIPAddress in 
('54.240.193.129','10.0.0.1')
and errorMessage like '%Failed authentication%'
order by eventTime desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#   eventversion  \
# 0         1.08
# 1         1.08
# 2         1.08
# 3         1.08
#
#                                                                                                                                             useridentity  \
# 0  {type=IAMUser, principalid=AIDA5HYDRCU67CLVSJXEC, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=ec2_fullaccess_user, se...
# 1  {type=IAMUser, principalid=AIDA5HYDRCU6VJV47ANAD, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=admin_user, sessioncont...
# 2  {type=IAMUser, principalid=AIDA5HYDRCU6QQS54AYSS, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=testuser, sessioncontex...
# 3  {type=IAMUser, principalid=AIDA5HYDRCU6TR5PFZSF2, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=jerchen, sessioncontext...
#
#               eventtime           eventsource     eventname  awsregion  \
# 0  2021-10-30T22:22:51Z  signin.amazonaws.com  ConsoleLogin  us-east-1
# 1  2021-10-30T22:22:39Z  signin.amazonaws.com  ConsoleLogin  us-east-1
# 2  2021-10-30T22:22:29Z  signin.amazonaws.com  ConsoleLogin  us-east-1
# 3  2021-10-30T22:14:23Z  signin.amazonaws.com  ConsoleLogin  us-east-1
#
#   sourceipaddress  \
# 0  54.240.193.129
# 1  54.240.193.129
# 2  54.240.193.129
# 3  54.240.193.129
#
#                                                                             useragent  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
#
#   errorcode           errormessage  ... requestid  \
# 0      None  Failed authentication  ...      None
# 1      None  Failed authentication  ...      None
# 2      None  Failed authentication  ...      None
# 3      None  Failed authentication  ...      None
#
#                                 eventid resources         eventtype  \
# 0  edf3e334-9fb3-450a-8552-9987e55e0e3f      None  AwsConsoleSignIn
# 1  e18dbdbe-b3b2-4ddb-983f-c06d56eadea3      None  AwsConsoleSignIn
# 2  52febd4b-28df-4ed5-90fc-f34726f36b6a      None  AwsConsoleSignIn
# 3  f6f2ecb7-232d-49bb-be48-21bb5e8555c7      None  AwsConsoleSignIn
#
#   apiversion readonly recipientaccountid serviceeventdetails sharedeventid  \
# 0       None    false       910003606845                None          None
# 1       None    false       910003606845                None          None
# 2       None    false       910003606845                None          None
# 3       None    false       910003606845                None          None
#
#   vpcendpointid
# 0          None
# 1          None
# 2          None
# 3          None
#
# [4 rows x 23 columns]

# %%
query = """
select *
from cloudtrail_logs
where errorCode  
('Client.UnauthorizedOperation','Client.InvalidPermission.NotFound','Client.OperationNotPermitted','AccessDenied')
and useridentity.arn like '%iam%'
order by eventTime desc;
"""
results = pd.read_sql(query, conn)
results

# %%
query = """
select *
from cloudtrail_logs
where errorMessage like '%Failed authentication%' 
and userIdentity.type = 'IAMUser'
order by eventTime desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#   eventversion  \
# 0         1.08
# 1         1.08
# 2         1.08
# 3         1.08
#
#                                                                                                                                             useridentity  \
# 0  {type=IAMUser, principalid=AIDA5HYDRCU67CLVSJXEC, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=ec2_fullaccess_user, se...
# 1  {type=IAMUser, principalid=AIDA5HYDRCU6VJV47ANAD, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=admin_user, sessioncont...
# 2  {type=IAMUser, principalid=AIDA5HYDRCU6QQS54AYSS, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=testuser, sessioncontex...
# 3  {type=IAMUser, principalid=AIDA5HYDRCU6TR5PFZSF2, arn=null, accountid=910003606845, invokedby=null, accesskeyid=, username=jerchen, sessioncontext...
#
#               eventtime           eventsource     eventname  awsregion  \
# 0  2021-10-30T22:22:51Z  signin.amazonaws.com  ConsoleLogin  us-east-1
# 1  2021-10-30T22:22:39Z  signin.amazonaws.com  ConsoleLogin  us-east-1
# 2  2021-10-30T22:22:29Z  signin.amazonaws.com  ConsoleLogin  us-east-1
# 3  2021-10-30T22:14:23Z  signin.amazonaws.com  ConsoleLogin  us-east-1
#
#   sourceipaddress  \
# 0  54.240.193.129
# 1  54.240.193.129
# 2  54.240.193.129
# 3  54.240.193.129
#
#                                                                             useragent  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:91.0) Gecko/20100101 Firefox/91.0
#
#   errorcode           errormessage  ... requestid  \
# 0      None  Failed authentication  ...      None
# 1      None  Failed authentication  ...      None
# 2      None  Failed authentication  ...      None
# 3      None  Failed authentication  ...      None
#
#                                 eventid resources         eventtype  \
# 0  edf3e334-9fb3-450a-8552-9987e55e0e3f      None  AwsConsoleSignIn
# 1  e18dbdbe-b3b2-4ddb-983f-c06d56eadea3      None  AwsConsoleSignIn
# 2  52febd4b-28df-4ed5-90fc-f34726f36b6a      None  AwsConsoleSignIn
# 3  f6f2ecb7-232d-49bb-be48-21bb5e8555c7      None  AwsConsoleSignIn
#
#   apiversion readonly recipientaccountid serviceeventdetails sharedeventid  \
# 0       None    false       910003606845                None          None
# 1       None    false       910003606845                None          None
# 2       None    false       910003606845                None          None
# 3       None    false       910003606845                None          None
#
#   vpcendpointid
# 0          None
# 1          None
# 2          None
# 3          None
#
# [4 rows x 23 columns]

# %%
query = """
select *
from cloudtrail_logs
where errorCode in ('Client.UnauthorizedOperation','Client.InvalidPermission.NotFound','Client.OperationNotPermitted','AccessDenied')
and useridentity.arn like '%iam%'
and eventTime >= '2021-10-14T11:45:00Z'
and eventTime < '2021-10-14T11:45:30Z'
order by eventTime desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#    eventversion  \
# 0          1.08
# 1          1.08
# 2          1.08
# 3          1.08
# 4          1.08
# 5          1.08
# 6          1.08
# 7          1.08
# 8          1.08
# 9          1.08
# 10         1.08
# 11         1.08
# 12         1.08
# 13         1.08
# 14         1.08
# 15         1.08
# 16         1.08
# 17         1.08
# 18         1.08
# 19         1.08
# 20         1.08
# 21         1.08
# 22         1.08
# 23         1.08
# 24         1.08
# 25         1.08
# 26         1.08
# 27         1.08
# 28         1.08
# 29         1.08
#
#                                                                                                                                              useridentity  \
# 0   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 1   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 2   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 3   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 4   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 5   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 6   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 7   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 8   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 9   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 10  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 11  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 12  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 13  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 14  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 15  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 16  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 17  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 18  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 19  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 20  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 21  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 22  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 23  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 24  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 25  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 26  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 27  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 28  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 29  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
#
#                eventtime       eventsource     eventname       awsregion  \
# 0   2021-10-14T11:45:29Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 1   2021-10-14T11:45:29Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 2   2021-10-14T11:45:27Z  s3.amazonaws.com  DeleteBucket       us-west-2
# 3   2021-10-14T11:45:26Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 4   2021-10-14T11:45:26Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 5   2021-10-14T11:45:24Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 6   2021-10-14T11:45:22Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 7   2021-10-14T11:45:20Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 8   2021-10-14T11:45:20Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 9   2021-10-14T11:45:20Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 10  2021-10-14T11:45:19Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 11  2021-10-14T11:45:19Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 12  2021-10-14T11:45:17Z  s3.amazonaws.com  DeleteBucket  ap-southeast-1
# 13  2021-10-14T11:45:15Z  s3.amazonaws.com  DeleteBucket  ap-southeast-1
# 14  2021-10-14T11:45:13Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 15  2021-10-14T11:45:11Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 16  2021-10-14T11:45:10Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 17  2021-10-14T11:45:09Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 18  2021-10-14T11:45:07Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 19  2021-10-14T11:45:07Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 20  2021-10-14T11:45:07Z  s3.amazonaws.com  DeleteBucket       us-west-2
# 21  2021-10-14T11:45:06Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 22  2021-10-14T11:45:06Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 23  2021-10-14T11:45:04Z  s3.amazonaws.com  DeleteBucket       us-west-2
# 24  2021-10-14T11:45:03Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 25  2021-10-14T11:45:03Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 26  2021-10-14T11:45:03Z  s3.amazonaws.com  DeleteBucket  ap-southeast-2
# 27  2021-10-14T11:45:01Z  s3.amazonaws.com  DeleteBucket       us-east-1
# 28  2021-10-14T11:45:01Z  s3.amazonaws.com  DeleteBucket       us-west-2
# 29  2021-10-14T11:45:00Z  s3.amazonaws.com  DeleteBucket       us-west-1
#
#    sourceipaddress  \
# 0     44.193.5.143
# 1     44.193.5.143
# 2     44.193.5.143
# 3     44.193.5.143
# 4     44.193.5.143
# 5     44.193.5.143
# 6     44.193.5.143
# 7     44.193.5.143
# 8     44.193.5.143
# 9     44.193.5.143
# 10    44.193.5.143
# 11    44.193.5.143
# 12    44.193.5.143
# 13    44.193.5.143
# 14    44.193.5.143
# 15    44.193.5.143
# 16    44.193.5.143
# 17    44.193.5.143
# 18    44.193.5.143
# 19    44.193.5.143
# 20    44.193.5.143
# 21    44.193.5.143
# 22    44.193.5.143
# 23    44.193.5.143
# 24    44.193.5.143
# 25    44.193.5.143
# 26    44.193.5.143
# 27    44.193.5.143
# 28    44.193.5.143
# 29    44.193.5.143
#
#                                                                                                              useragent  \
# 0   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 1   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 2   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 3   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 4   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 5   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 6   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 7   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 8   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 9   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 10  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 11  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 12  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 13  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 14  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 15  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 16  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 17  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 18  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 19  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 20  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 21  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 22  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 23  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 24  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 25  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 26  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 27  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 28  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 29  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
#
#        errorcode   errormessage  ...         requestid  \
# 0   AccessDenied  Access Denied  ...  0MT63FNP2HXM9DVY
# 1   AccessDenied  Access Denied  ...  0MT9BFSJ657DX8HQ
# 2   AccessDenied  Access Denied  ...  X92V1F9AQSKV2ZV3
# 3   AccessDenied  Access Denied  ...  6N7W5B5TY865G4E4
# 4   AccessDenied  Access Denied  ...  6N7KQ4RM7MQWZN01
# 5   AccessDenied  Access Denied  ...  CJMGJSKE1V7X1Z76
# 6   AccessDenied  Access Denied  ...  J36JV131Z125DTWW
# 7   AccessDenied  Access Denied  ...  CAV9K2ZX460JB423
# 8   AccessDenied  Access Denied  ...  CAV3XX7P16FCYBXN
# 9   AccessDenied  Access Denied  ...  CAV7Q373DT79JFVT
# 10  AccessDenied  Access Denied  ...  ZQC88CKM9QCS8J16
# 11  AccessDenied  Access Denied  ...  ZQCEDQXF1TQ0D8YG
# 12  AccessDenied  Access Denied  ...  8AVCATGYSA5F043S
# 13  AccessDenied  Access Denied  ...  VKJYZ6W8J0RYXM28
# 14  AccessDenied  Access Denied  ...  J0M6Q2K46F6R5ZDY
# 15  AccessDenied  Access Denied  ...  MFJY2G2SMD4K1GR3
# 16  AccessDenied  Access Denied  ...  ES5TS7424YEPRGQ4
# 17  AccessDenied  Access Denied  ...  39WE4KVM7D50QYYE
# 18  AccessDenied  Access Denied  ...  FY7697Y5SN0C6Q95
# 19  AccessDenied  Access Denied  ...  FY7047VPFWXE4HRY
# 20  AccessDenied  Access Denied  ...  FY7BEF7Y7JFDB889
# 21  AccessDenied  Access Denied  ...  JVJY97GZMNN7SPAH
# 22  AccessDenied  Access Denied  ...  JVJZ0KJXG0E8FZ32
# 23  AccessDenied  Access Denied  ...  2YJ0TFPBE1KVD62V
# 24  AccessDenied  Access Denied  ...  25SMACDQ159EDDM8
# 25  AccessDenied  Access Denied  ...  25SM0QB17TBFDYS2
# 26  AccessDenied  Access Denied  ...  25SM31K1TMSKNVM8
# 27  AccessDenied  Access Denied  ...  NFGQEDXXZJ6H10MK
# 28  AccessDenied  Access Denied  ...  NFGT5HNNWX62GQS2
# 29  AccessDenied  Access Denied  ...  K19DQCX0A55E32X0
#
#                                  eventid  \
# 0   746c66f3-8189-44ef-b646-3bdbdfae3b62
# 1   efaafe54-ce44-43bb-ada2-7c4e5358c45c
# 2   d8095b3e-ea48-405c-9a5a-722672ff0d44
# 3   a3c2ca3b-24bc-470b-8670-5ee690a8ce75
# 4   a56d3a0c-50d9-4103-990a-6e58a9ac6ca7
# 5   bd1666c1-7236-40ed-a2d2-f90498a15969
# 6   b0f0e955-5489-43ee-b4cb-ada59c82a224
# 7   fb604ec7-3cd0-42fb-8fee-05de6b72ccaf
# 8   b1f4cb45-920a-4373-9a82-3df67c3f0a1d
# 9   6b685384-ff7e-4363-a907-014b8b988526
# 10  7d526904-7943-4a7d-9be3-31a00dcd7f25
# 11  5778a433-7cd6-4bf5-9cdc-64cfbb0160fc
# 12  1d964a15-ce80-4648-a5d3-21558ae392ea
# 13  0cd588ed-5b5c-4a2b-acb4-b265cdd9f12f
# 14  c824ed28-cf51-4bc2-8d16-05b8145b7139
# 15  b100ba1e-61d0-43a2-8aa0-de25c082194e
# 16  909bfde1-6aad-4c0b-9528-faf29f9c0629
# 17  6015befa-dad7-4218-aa3a-7e444d944a2b
# 18  11a300c4-c910-41d3-8edd-6accf9a33738
# 19  55fd7ceb-b9dd-43dc-a4e3-c35590fd6c65
# 20  3543f1a7-7a1d-442c-9ec1-8a189a321fd5
# 21  a6c26dc0-2bd5-438f-9769-2b18bd0ccd14
# 22  c545a84e-f599-427b-bda0-586cb5fab797
# 23  2b1ff236-f209-4d89-baba-95ba1b2a8ef4
# 24  cdc4c331-5b63-4f73-b088-482da24fe93c
# 25  41b82df9-a2eb-4181-829a-6c19a1bc3bae
# 26  cc4bf6e8-661a-4fd6-8e02-9e4a8f79c746
# 27  6c99a0b7-3ffb-401c-8e2c-4ace1973d6e4
# 28  4f2fcf77-2d42-4a46-a705-b8f1ad9b3332
# 29  e2f6c1ce-2eb4-4bb7-bf4b-971858a71470
#
#                                                                                                                              resources  \
# 0                           [{arn=arn:aws:s3:::sagemaker-studio-us-east-1-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 1                      [{arn=arn:aws:s3:::sagemaker-studio-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 2                         [{arn=arn:aws:s3:::sagemaker-studio-910003606845-ng9u93sj4tf, accountid=910003606845, type=AWS::S3::Bucket}]
# 3                    [{arn=arn:aws:s3:::sagemaker-notebook-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 4                         [{arn=arn:aws:s3:::sagemaker-studio-910003606845-mbuglbudgrc, accountid=910003606845, type=AWS::S3::Bucket}]
# 5                             [{arn=arn:aws:s3:::sagemaker-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 6                                [{arn=arn:aws:s3:::s3-lens-dashboard-export-data-2021, accountid=910003606845, type=AWS::S3::Bucket}]
# 7                                        [{arn=arn:aws:s3:::s3-health-stack-106-bucket, accountid=910003606845, type=AWS::S3::Bucket}]
# 8   [{arn=arn:aws:s3:::reinforce2021-tdr254-clo-athenaqueryresultsbucket-1inggpjk2pxo7, accountid=910003606845, type=AWS::S3::Bucket}]
# 9                  [{arn=arn:aws:s3:::reinforce2021-tdr254-910003606845-us-east-1-data, accountid=910003606845, type=AWS::S3::Bucket}]
# 10                        [{arn=arn:aws:s3:::reinforce2021-cloudtrail-jerchen-20211014, accountid=910003606845, type=AWS::S3::Bucket}]
# 11                                                [{arn=arn:aws:s3:::pyky2-report-repo, accountid=910003606845, type=AWS::S3::Bucket}]
# 12         [{arn=arn:aws:s3:::photoalbumsf3dd7d27073c40d4b032fa95d3f04c7e104750-master, accountid=910003606845, type=AWS::S3::Bucket}]
# 13                  [{arn=arn:aws:s3:::photoalbums-20201118111318-hostingbucket-master, accountid=910003606845, type=AWS::S3::Bucket}]
# 14                   [{arn=arn:aws:s3:::openaq-forecasting-910003606845-ap-southeast-2, accountid=910003606845, type=AWS::S3::Bucket}]
# 15                                          [{arn=arn:aws:s3:::my-test-bucket-20191011, accountid=910003606845, type=AWS::S3::Bucket}]
# 16                            [{arn=arn:aws:s3:::my-athena-query-result-s3-bucket-2021, accountid=910003606845, type=AWS::S3::Bucket}]
# 17                   [{arn=arn:aws:s3:::mlops-aqf-artifact-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 18                                         [{arn=arn:aws:s3:::lf-workshop-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 19                                        [{arn=arn:aws:s3:::lf-data-lake-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 20                             [{arn=arn:aws:s3:::jc-lambda-twitter-python-test-bucket, accountid=910003606845, type=AWS::S3::Bucket}]
# 21                     [{arn=arn:aws:s3:::elasticbeanstalk-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 22                                          [{arn=arn:aws:s3:::heath-api-lab-s3-bucket, accountid=910003606845, type=AWS::S3::Bucket}]
# 23                     [{arn=arn:aws:s3:::do-not-delete-gatedgarden-audit-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 24                                             [{arn=arn:aws:s3:::connect-b8df6a1f839a, accountid=910003606845, type=AWS::S3::Bucket}]
# 25                                             [{arn=arn:aws:s3:::connect-08294e685d8f, accountid=910003606845, type=AWS::S3::Bucket}]
# 26                                       [{arn=arn:aws:s3:::config-bucket-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 27  [{arn=arn:aws:s3:::cloudtrail-awslogs-910003606845-k9lbmss8-isengard-do-not-delete, accountid=910003606845, type=AWS::S3::Bucket}]
# 28                              [{arn=arn:aws:s3:::cf-templates-d2673lchlwob-us-west-2, accountid=910003606845, type=AWS::S3::Bucket}]
# 29                              [{arn=arn:aws:s3:::cf-templates-d2673lchlwob-us-west-1, accountid=910003606845, type=AWS::S3::Bucket}]
#
#      eventtype apiversion readonly recipientaccountid serviceeventdetails  \
# 0   AwsApiCall       None    false       910003606845                None
# 1   AwsApiCall       None    false       910003606845                None
# 2   AwsApiCall       None    false       910003606845                None
# 3   AwsApiCall       None    false       910003606845                None
# 4   AwsApiCall       None    false       910003606845                None
# 5   AwsApiCall       None    false       910003606845                None
# 6   AwsApiCall       None    false       910003606845                None
# 7   AwsApiCall       None    false       910003606845                None
# 8   AwsApiCall       None    false       910003606845                None
# 9   AwsApiCall       None    false       910003606845                None
# 10  AwsApiCall       None    false       910003606845                None
# 11  AwsApiCall       None    false       910003606845                None
# 12  AwsApiCall       None    false       910003606845                None
# 13  AwsApiCall       None    false       910003606845                None
# 14  AwsApiCall       None    false       910003606845                None
# 15  AwsApiCall       None    false       910003606845                None
# 16  AwsApiCall       None    false       910003606845                None
# 17  AwsApiCall       None    false       910003606845                None
# 18  AwsApiCall       None    false       910003606845                None
# 19  AwsApiCall       None    false       910003606845                None
# 20  AwsApiCall       None    false       910003606845                None
# 21  AwsApiCall       None    false       910003606845                None
# 22  AwsApiCall       None    false       910003606845                None
# 23  AwsApiCall       None    false       910003606845                None
# 24  AwsApiCall       None    false       910003606845                None
# 25  AwsApiCall       None    false       910003606845                None
# 26  AwsApiCall       None    false       910003606845                None
# 27  AwsApiCall       None    false       910003606845                None
# 28  AwsApiCall       None    false       910003606845                None
# 29  AwsApiCall       None    false       910003606845                None
#
#    sharedeventid vpcendpointid
# 0           None          None
# 1           None          None
# 2           None          None
# 3           None          None
# 4           None          None
# 5           None          None
# 6           None          None
# 7           None          None
# 8           None          None
# 9           None          None
# 10          None          None
# 11          None          None
# 12          None          None
# 13          None          None
# 14          None          None
# 15          None          None
# 16          None          None
# 17          None          None
# 18          None          None
# 19          None          None
# 20          None          None
# 21          None          None
# 22          None          None
# 23          None          None
# 24          None          None
# 25          None          None
# 26          None          None
# 27          None          None
# 28          None          None
# 29          None          None
#
# [30 rows x 23 columns]

# %%
query = """
select eventTime, eventSource, eventName, errorCode, errorMessage, responseElements, awsRegion, userIdentity.arn, sourceIPAddress, userAgent
from cloudtrail_logs
where errorCode in ('Client.UnauthorizedOperation','Client.InvalidPermission.NotFound','Client.OperationNotPermitted','AccessDenied')
and useridentity.arn like '%iam%'
and eventTime >= '2021-10-14T11:45:00Z'
and eventTime < '2021-10-14T11:45:30Z'
order by eventTime desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#                eventTime       eventSource     eventName     errorCode  \
# 0   2021-10-14T11:45:29Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 1   2021-10-14T11:45:29Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 2   2021-10-14T11:45:27Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 3   2021-10-14T11:45:26Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 4   2021-10-14T11:45:26Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 5   2021-10-14T11:45:24Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 6   2021-10-14T11:45:22Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 7   2021-10-14T11:45:20Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 8   2021-10-14T11:45:20Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 9   2021-10-14T11:45:20Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 10  2021-10-14T11:45:19Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 11  2021-10-14T11:45:19Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 12  2021-10-14T11:45:17Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 13  2021-10-14T11:45:15Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 14  2021-10-14T11:45:13Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 15  2021-10-14T11:45:11Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 16  2021-10-14T11:45:10Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 17  2021-10-14T11:45:09Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 18  2021-10-14T11:45:07Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 19  2021-10-14T11:45:07Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 20  2021-10-14T11:45:07Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 21  2021-10-14T11:45:06Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 22  2021-10-14T11:45:06Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 23  2021-10-14T11:45:04Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 24  2021-10-14T11:45:03Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 25  2021-10-14T11:45:03Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 26  2021-10-14T11:45:03Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 27  2021-10-14T11:45:01Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 28  2021-10-14T11:45:01Z  s3.amazonaws.com  DeleteBucket  AccessDenied
# 29  2021-10-14T11:45:00Z  s3.amazonaws.com  DeleteBucket  AccessDenied
#
#      errorMessage responseElements       awsRegion  \
# 0   Access Denied             null  ap-southeast-2
# 1   Access Denied             null       us-east-1
# 2   Access Denied             null       us-west-2
# 3   Access Denied             null  ap-southeast-2
# 4   Access Denied             null       us-east-1
# 5   Access Denied             null  ap-southeast-2
# 6   Access Denied             null  ap-southeast-2
# 7   Access Denied             null       us-east-1
# 8   Access Denied             null       us-east-1
# 9   Access Denied             null       us-east-1
# 10  Access Denied             null       us-east-1
# 11  Access Denied             null  ap-southeast-2
# 12  Access Denied             null  ap-southeast-1
# 13  Access Denied             null  ap-southeast-1
# 14  Access Denied             null  ap-southeast-2
# 15  Access Denied             null  ap-southeast-2
# 16  Access Denied             null       us-east-1
# 17  Access Denied             null  ap-southeast-2
# 18  Access Denied             null       us-east-1
# 19  Access Denied             null       us-east-1
# 20  Access Denied             null       us-west-2
# 21  Access Denied             null  ap-southeast-2
# 22  Access Denied             null       us-east-1
# 23  Access Denied             null       us-west-2
# 24  Access Denied             null       us-east-1
# 25  Access Denied             null  ap-southeast-2
# 26  Access Denied             null       us-east-1
# 27  Access Denied             null       us-west-2
# 28  Access Denied             null       us-east-1
# 29  Access Denied             null       us-west-1
#
#                                                    arn sourceIPAddress  \
# 0   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 1   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 2   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 3   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 4   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 5   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 6   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 7   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 8   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 9   arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 10  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 11  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 12  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 13  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 14  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 15  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 16  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 17  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 18  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 19  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 20  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 21  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 22  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 23  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 24  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 25  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 26  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 27  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 28  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
# 29  arn:aws:iam::910003606845:user/compromized_account    44.193.5.143
#
#                                                                                                              userAgent
# 0   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 1   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 2   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 3   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 4   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 5   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 6   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 7   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 8   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 9   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 10  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 11  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 12  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 13  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 14  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 15  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 16  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 17  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 18  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 19  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 20  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 21  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 22  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 23  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 24  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 25  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 26  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 27  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 28  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 29  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]

# %%
query = """
select userIdentity.arn, count(*) as total
from cloudtrail_logs
where errorCode in ('Client.UnauthorizedOperation','Client.InvalidPermission.NotFound','Client.OperationNotPermitted','AccessDenied')
and useridentity.arn like '%iam%'
and eventTime >= '2021-10-13T11:45:00Z'
and eventTime < '2021-10-15T11:45:30Z'
group by userIdentity.arn
order by total desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#                                                   arn  total
# 0  arn:aws:iam::910003606845:user/compromized_account     51

# %% [markdown]
# ### Step 2 - Initial investigation
# Now that you have identified the potential IAM entity which has been compromised, you should do further investigations to identify what the entity has been attemping to do.

# %%
query = """
select *
from cloudtrail_logs
where userIdentity.arn='arn:aws:iam::910003606845:user/compromized_account'
and eventTime >= '2021-10-13T11:45:00Z'
and eventTime < '2021-10-15T11:45:30Z'
order by eventTime desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#    eventversion  \
# 0          1.08
# 1          1.08
# 2          1.08
# 3          1.08
# 4          1.08
# 5          1.08
# 6          1.08
# 7          1.08
# 8          1.08
# 9          1.08
# 10         1.08
# 11         1.08
# 12         1.08
# 13         1.08
# 14         1.08
# 15         1.08
# 16         1.08
# 17         1.08
# 18         1.08
# 19         1.08
# 20         1.08
# 21         1.08
# 22         1.08
# 23         1.08
# 24         1.08
# 25         1.08
# 26         1.08
# 27         1.08
# 28         1.08
# 29         1.08
# 30         1.08
# 31         1.08
# 32         1.08
# 33         1.08
# 34         1.08
# 35         1.08
# 36         1.08
# 37         1.08
# 38         1.08
# 39         1.08
# 40         1.08
# 41         1.08
# 42         1.08
# 43         1.08
# 44         1.08
# 45         1.08
# 46         1.08
# 47         1.08
# 48         1.08
# 49         1.08
# 50         1.08
# 51         1.08
# 52         1.08
# 53         1.08
# 54         1.08
# 55         1.08
# 56         1.08
#
#                                                                                                                                              useridentity  \
# 0   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 1   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 2   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 3   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 4   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 5   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 6   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 7   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 8   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 9   {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 10  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 11  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 12  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 13  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 14  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 15  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 16  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 17  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 18  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 19  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 20  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 21  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 22  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 23  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 24  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 25  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 26  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 27  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 28  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 29  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 30  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 31  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 32  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 33  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 34  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 35  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 36  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 37  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 38  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 39  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 40  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 41  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 42  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 43  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 44  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 45  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 46  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 47  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 48  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 49  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 50  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 51  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 52  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 53  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 54  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 55  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
# 56  {type=IAMUser, principalid=AIDA5HYDRCU62STTT5MQD, arn=arn:aws:iam::910003606845:user/compromized_account, accountid=910003606845, invokedby=null, ...
#
#                eventtime               eventsource          eventname  \
# 0   2021-10-14T11:45:35Z         ec2.amazonaws.com       RunInstances
# 1   2021-10-14T11:45:33Z         iam.amazonaws.com         CreateUser
# 2   2021-10-14T11:45:32Z          s3.amazonaws.com       DeleteBucket
# 3   2021-10-14T11:45:32Z          s3.amazonaws.com       DeleteBucket
# 4   2021-10-14T11:45:30Z          s3.amazonaws.com       DeleteBucket
# 5   2021-10-14T11:45:30Z          s3.amazonaws.com       DeleteBucket
# 6   2021-10-14T11:45:30Z          s3.amazonaws.com       DeleteBucket
# 7   2021-10-14T11:45:29Z          s3.amazonaws.com       DeleteBucket
# 8   2021-10-14T11:45:29Z          s3.amazonaws.com       DeleteBucket
# 9   2021-10-14T11:45:27Z          s3.amazonaws.com       DeleteBucket
# 10  2021-10-14T11:45:26Z          s3.amazonaws.com       DeleteBucket
# 11  2021-10-14T11:45:26Z          s3.amazonaws.com       DeleteBucket
# 12  2021-10-14T11:45:24Z          s3.amazonaws.com       DeleteBucket
# 13  2021-10-14T11:45:22Z          s3.amazonaws.com       DeleteBucket
# 14  2021-10-14T11:45:20Z          s3.amazonaws.com       DeleteBucket
# 15  2021-10-14T11:45:20Z          s3.amazonaws.com       DeleteBucket
# 16  2021-10-14T11:45:20Z          s3.amazonaws.com       DeleteBucket
# 17  2021-10-14T11:45:19Z          s3.amazonaws.com       DeleteBucket
# 18  2021-10-14T11:45:19Z          s3.amazonaws.com       DeleteBucket
# 19  2021-10-14T11:45:17Z          s3.amazonaws.com       DeleteBucket
# 20  2021-10-14T11:45:15Z          s3.amazonaws.com       DeleteBucket
# 21  2021-10-14T11:45:13Z          s3.amazonaws.com       DeleteBucket
# 22  2021-10-14T11:45:11Z          s3.amazonaws.com       DeleteBucket
# 23  2021-10-14T11:45:10Z          s3.amazonaws.com       DeleteBucket
# 24  2021-10-14T11:45:09Z          s3.amazonaws.com       DeleteBucket
# 25  2021-10-14T11:45:07Z          s3.amazonaws.com       DeleteBucket
# 26  2021-10-14T11:45:07Z          s3.amazonaws.com       DeleteBucket
# 27  2021-10-14T11:45:07Z          s3.amazonaws.com       DeleteBucket
# 28  2021-10-14T11:45:06Z          s3.amazonaws.com       DeleteBucket
# 29  2021-10-14T11:45:06Z          s3.amazonaws.com       DeleteBucket
# 30  2021-10-14T11:45:04Z          s3.amazonaws.com       DeleteBucket
# 31  2021-10-14T11:45:03Z          s3.amazonaws.com       DeleteBucket
# 32  2021-10-14T11:45:03Z          s3.amazonaws.com       DeleteBucket
# 33  2021-10-14T11:45:03Z          s3.amazonaws.com       DeleteBucket
# 34  2021-10-14T11:45:01Z          s3.amazonaws.com       DeleteBucket
# 35  2021-10-14T11:45:01Z          s3.amazonaws.com       DeleteBucket
# 36  2021-10-14T11:45:00Z          s3.amazonaws.com       DeleteBucket
# 37  2021-10-14T11:44:59Z          s3.amazonaws.com       DeleteBucket
# 38  2021-10-14T11:44:59Z          s3.amazonaws.com       DeleteBucket
# 39  2021-10-14T11:44:58Z          s3.amazonaws.com       DeleteBucket
# 40  2021-10-14T11:44:56Z          s3.amazonaws.com       DeleteBucket
# 41  2021-10-14T11:44:55Z          s3.amazonaws.com       DeleteBucket
# 42  2021-10-14T11:44:54Z          s3.amazonaws.com       DeleteBucket
# 43  2021-10-14T11:44:54Z          s3.amazonaws.com       DeleteBucket
# 44  2021-10-14T11:44:54Z          s3.amazonaws.com       DeleteBucket
# 45  2021-10-14T11:44:52Z          s3.amazonaws.com       DeleteBucket
# 46  2021-10-14T11:44:52Z          s3.amazonaws.com       DeleteBucket
# 47  2021-10-14T11:44:51Z          s3.amazonaws.com       DeleteBucket
# 48  2021-10-14T11:44:49Z          s3.amazonaws.com       DeleteBucket
# 49  2021-10-14T11:44:49Z          s3.amazonaws.com       DeleteBucket
# 50  2021-10-14T11:44:49Z          s3.amazonaws.com       DeleteBucket
# 51  2021-10-14T11:44:47Z   guardduty.amazonaws.com      ListDetectors
# 52  2021-10-14T11:44:47Z  cloudtrail.amazonaws.com         ListTrails
# 53  2021-10-14T11:44:46Z         iam.amazonaws.com          ListUsers
# 54  2021-10-14T11:44:46Z    dynamodb.amazonaws.com         ListTables
# 55  2021-10-14T11:44:46Z          s3.amazonaws.com        ListBuckets
# 56  2021-10-14T11:44:44Z         ec2.amazonaws.com  DescribeInstances
#
#          awsregion sourceipaddress  \
# 0        us-east-1    44.193.5.143
# 1        us-east-1    44.193.5.143
# 2   ap-southeast-2    44.193.5.143
# 3        us-east-1    44.193.5.143
# 4        us-west-2    44.193.5.143
# 5        us-east-1    44.193.5.143
# 6        us-east-1    44.193.5.143
# 7   ap-southeast-2    44.193.5.143
# 8        us-east-1    44.193.5.143
# 9        us-west-2    44.193.5.143
# 10  ap-southeast-2    44.193.5.143
# 11       us-east-1    44.193.5.143
# 12  ap-southeast-2    44.193.5.143
# 13  ap-southeast-2    44.193.5.143
# 14       us-east-1    44.193.5.143
# 15       us-east-1    44.193.5.143
# 16       us-east-1    44.193.5.143
# 17  ap-southeast-2    44.193.5.143
# 18       us-east-1    44.193.5.143
# 19  ap-southeast-1    44.193.5.143
# 20  ap-southeast-1    44.193.5.143
# 21  ap-southeast-2    44.193.5.143
# 22  ap-southeast-2    44.193.5.143
# 23       us-east-1    44.193.5.143
# 24  ap-southeast-2    44.193.5.143
# 25       us-west-2    44.193.5.143
# 26       us-east-1    44.193.5.143
# 27       us-east-1    44.193.5.143
# 28  ap-southeast-2    44.193.5.143
# 29       us-east-1    44.193.5.143
# 30       us-west-2    44.193.5.143
# 31       us-east-1    44.193.5.143
# 32  ap-southeast-2    44.193.5.143
# 33       us-east-1    44.193.5.143
# 34       us-west-2    44.193.5.143
# 35       us-east-1    44.193.5.143
# 36       us-west-1    44.193.5.143
# 37       us-east-2    44.193.5.143
# 38       us-east-1    44.193.5.143
# 39  ap-southeast-2    44.193.5.143
# 40  ap-southeast-2    44.193.5.143
# 41       us-east-1    44.193.5.143
# 42  ap-southeast-1    44.193.5.143
# 43       us-east-1    44.193.5.143
# 44       us-east-1    44.193.5.143
# 45       us-east-1    44.193.5.143
# 46       us-east-1    44.193.5.143
# 47  ap-southeast-1    44.193.5.143
# 48       us-east-1    44.193.5.143
# 49  ap-southeast-2    44.193.5.143
# 50       us-east-1    44.193.5.143
# 51       us-east-1    44.193.5.143
# 52       us-east-1    44.193.5.143
# 53       us-east-1    44.193.5.143
# 54       us-east-1    44.193.5.143
# 55       us-east-1    44.193.5.143
# 56       us-east-1    44.193.5.143
#
#                                                                                                              useragent  \
# 0     Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100
# 1     Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100
# 2   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 3   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 4   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 5   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 6   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 7   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 8   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 9   [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 10  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 11  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 12  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 13  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 14  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 15  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 16  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 17  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 18  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 19  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 20  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 21  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 22  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 23  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 24  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 25  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 26  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 27  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 28  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 29  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 30  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 31  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 32  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 33  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 34  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 35  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 36  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 37  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 38  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 39  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 40  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 41  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 42  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 43  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 44  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 45  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 46  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 47  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 48  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 49  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 50  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 51    Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100
# 52    Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100
# 53    Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100
# 54    Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100
# 55  [Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100]
# 56    Boto3/1.17.100 Python/3.8.11 Linux/4.14.243-194.434.amzn2.x86_64 exec-env/AWS_Lambda_python3.8 Botocore/1.20.100
#
#                        errorcode  \
# 0   Client.UnauthorizedOperation
# 1                   AccessDenied
# 2                   AccessDenied
# 3                   AccessDenied
# 4                   AccessDenied
# 5                   AccessDenied
# 6                   AccessDenied
# 7                   AccessDenied
# 8                   AccessDenied
# 9                   AccessDenied
# 10                  AccessDenied
# 11                  AccessDenied
# 12                  AccessDenied
# 13                  AccessDenied
# 14                  AccessDenied
# 15                  AccessDenied
# 16                  AccessDenied
# 17                  AccessDenied
# 18                  AccessDenied
# 19                  AccessDenied
# 20                  AccessDenied
# 21                  AccessDenied
# 22                  AccessDenied
# 23                  AccessDenied
# 24                  AccessDenied
# 25                  AccessDenied
# 26                  AccessDenied
# 27                  AccessDenied
# 28                  AccessDenied
# 29                  AccessDenied
# 30                  AccessDenied
# 31                  AccessDenied
# 32                  AccessDenied
# 33                  AccessDenied
# 34                  AccessDenied
# 35                  AccessDenied
# 36                  AccessDenied
# 37                  AccessDenied
# 38                  AccessDenied
# 39                  AccessDenied
# 40                  AccessDenied
# 41                  AccessDenied
# 42                  AccessDenied
# 43                  AccessDenied
# 44                  AccessDenied
# 45                  AccessDenied
# 46                  AccessDenied
# 47                  AccessDenied
# 48                  AccessDenied
# 49                  AccessDenied
# 50                  AccessDenied
# 51                          None
# 52                          None
# 53                          None
# 54                          None
# 55                          None
# 56                          None
#
#                                                                                                                                              errormessage  \
# 0   You are not authorized to perform this operation. Encoded authorization failure message: DmQwpI7iNqoHnKipUCmUtSljfdN1s_cvS4M3bQLAnd5S1MO3_RSwTQdcM...
# 1   User: arn:aws:iam::910003606845:user/compromized_account is not authorized to perform: iam:CreateUser on resource: arn:aws:iam::910003606845:user/...
# 2                                                                                                                                           Access Denied
# 3                                                                                                                                           Access Denied
# 4                                                                                                                                           Access Denied
# 5                                                                                                                                           Access Denied
# 6                                                                                                                                           Access Denied
# 7                                                                                                                                           Access Denied
# 8                                                                                                                                           Access Denied
# 9                                                                                                                                           Access Denied
# 10                                                                                                                                          Access Denied
# 11                                                                                                                                          Access Denied
# 12                                                                                                                                          Access Denied
# 13                                                                                                                                          Access Denied
# 14                                                                                                                                          Access Denied
# 15                                                                                                                                          Access Denied
# 16                                                                                                                                          Access Denied
# 17                                                                                                                                          Access Denied
# 18                                                                                                                                          Access Denied
# 19                                                                                                                                          Access Denied
# 20                                                                                                                                          Access Denied
# 21                                                                                                                                          Access Denied
# 22                                                                                                                                          Access Denied
# 23                                                                                                                                          Access Denied
# 24                                                                                                                                          Access Denied
# 25                                                                                                                                          Access Denied
# 26                                                                                                                                          Access Denied
# 27                                                                                                                                          Access Denied
# 28                                                                                                                                          Access Denied
# 29                                                                                                                                          Access Denied
# 30                                                                                                                                          Access Denied
# 31                                                                                                                                          Access Denied
# 32                                                                                                                                          Access Denied
# 33                                                                                                                                          Access Denied
# 34                                                                                                                                          Access Denied
# 35                                                                                                                                          Access Denied
# 36                                                                                                                                          Access Denied
# 37                                                                                                                                          Access Denied
# 38                                                                                                                                          Access Denied
# 39                                                                                                                                          Access Denied
# 40                                                                                                                                          Access Denied
# 41                                                                                                                                          Access Denied
# 42                                                                                                                                          Access Denied
# 43                                                                                                                                          Access Denied
# 44                                                                                                                                          Access Denied
# 45                                                                                                                                          Access Denied
# 46                                                                                                                                          Access Denied
# 47                                                                                                                                          Access Denied
# 48                                                                                                                                          Access Denied
# 49                                                                                                                                          Access Denied
# 50                                                                                                                                          Access Denied
# 51                                                                                                                                                   None
# 52                                                                                                                                                   None
# 53                                                                                                                                                   None
# 54                                                                                                                                                   None
# 55                                                                                                                                                   None
# 56                                                                                                                                                   None
#
#     ...                                             requestid  \
# 0   ...                  4d6e5d4e-3979-444b-81fa-c13caa22152e
# 1   ...                  d9288e4f-199a-4642-9e8c-94c430588485
# 2   ...                                      G69M3P7FSX96EBQZ
# 3   ...                                      G69N1TXGQM9RM5NX
# 4   ...                                      GEQC1H8X6ENV7RXE
# 5   ...                                      GEQDAFQNRR62QZF2
# 6   ...                                      GEQ3DDZ2FS8E0X9K
# 7   ...                                      0MT9BFSJ657DX8HQ
# 8   ...                                      0MT63FNP2HXM9DVY
# 9   ...                                      X92V1F9AQSKV2ZV3
# 10  ...                                      6N7W5B5TY865G4E4
# 11  ...                                      6N7KQ4RM7MQWZN01
# 12  ...                                      CJMGJSKE1V7X1Z76
# 13  ...                                      J36JV131Z125DTWW
# 14  ...                                      CAV9K2ZX460JB423
# 15  ...                                      CAV3XX7P16FCYBXN
# 16  ...                                      CAV7Q373DT79JFVT
# 17  ...                                      ZQCEDQXF1TQ0D8YG
# 18  ...                                      ZQC88CKM9QCS8J16
# 19  ...                                      8AVCATGYSA5F043S
# 20  ...                                      VKJYZ6W8J0RYXM28
# 21  ...                                      J0M6Q2K46F6R5ZDY
# 22  ...                                      MFJY2G2SMD4K1GR3
# 23  ...                                      ES5TS7424YEPRGQ4
# 24  ...                                      39WE4KVM7D50QYYE
# 25  ...                                      FY7BEF7Y7JFDB889
# 26  ...                                      FY7697Y5SN0C6Q95
# 27  ...                                      FY7047VPFWXE4HRY
# 28  ...                                      JVJY97GZMNN7SPAH
# 29  ...                                      JVJZ0KJXG0E8FZ32
# 30  ...                                      2YJ0TFPBE1KVD62V
# 31  ...                                      25SMACDQ159EDDM8
# 32  ...                                      25SM31K1TMSKNVM8
# 33  ...                                      25SM0QB17TBFDYS2
# 34  ...                                      NFGT5HNNWX62GQS2
# 35  ...                                      NFGQEDXXZJ6H10MK
# 36  ...                                      K19DQCX0A55E32X0
# 37  ...                                      N84H4CPPKCEDHSXW
# 38  ...                                      N84PFC6GQ1BVQJ3D
# 39  ...                                      GKZ0332DGFDZJKHP
# 40  ...                                      7KSZ0ZG20MQJXT3S
# 41  ...                                      EA8YMAXYEED9JNXX
# 42  ...                                      0P53YG4FE4ASS2NQ
# 43  ...                                      0P57GQFT9EP6AS58
# 44  ...                                      0P590V61QCR68C88
# 45  ...                                      WDRJPC8E6PWDWT7N
# 46  ...                                      WDRK7QCCCFAQCZDW
# 47  ...                                      4E9X637WRG9A81BJ
# 48  ...                                      PK7WARNQ3T6B5G9P
# 49  ...                                      PK7PHTV9AWAB8PEX
# 50  ...                                      PK7JKP7AE4NKESXZ
# 51  ...                  b268017e-71f5-4359-9b46-e94c766bc6cb
# 52  ...                  352fecaa-b0f6-4cf3-b9c7-2bc3390cac7d
# 53  ...                  c44cf979-da9f-4708-b66e-da527b68cb97
# 54  ...  S5P31J5RU4LF2SJDK9MBBL1BVVVV4KQNSO5AEMVJF66Q9ASUAAJG
# 55  ...                                      VR17ZQAEY1QBFKBP
# 56  ...                  f4792e27-f1b3-458d-b868-163c987faa3f
#
#                                  eventid  \
# 0   357ec252-30ef-4b5e-996f-97e011d2e86e
# 1   b92881c7-6c00-4042-bc08-755a3421adf2
# 2   d0fb4977-ee74-4041-bec3-e20b8c8f3b54
# 3   97821658-bca9-4e08-b220-5b50bcb95487
# 4   e80940d2-916d-46bd-8a4b-15752419cd18
# 5   1192d194-f1cd-4187-991d-46ed3f026e9c
# 6   2cbc989a-c5db-4ccf-90e6-a3ae7c275149
# 7   efaafe54-ce44-43bb-ada2-7c4e5358c45c
# 8   746c66f3-8189-44ef-b646-3bdbdfae3b62
# 9   d8095b3e-ea48-405c-9a5a-722672ff0d44
# 10  a3c2ca3b-24bc-470b-8670-5ee690a8ce75
# 11  a56d3a0c-50d9-4103-990a-6e58a9ac6ca7
# 12  bd1666c1-7236-40ed-a2d2-f90498a15969
# 13  b0f0e955-5489-43ee-b4cb-ada59c82a224
# 14  fb604ec7-3cd0-42fb-8fee-05de6b72ccaf
# 15  b1f4cb45-920a-4373-9a82-3df67c3f0a1d
# 16  6b685384-ff7e-4363-a907-014b8b988526
# 17  5778a433-7cd6-4bf5-9cdc-64cfbb0160fc
# 18  7d526904-7943-4a7d-9be3-31a00dcd7f25
# 19  1d964a15-ce80-4648-a5d3-21558ae392ea
# 20  0cd588ed-5b5c-4a2b-acb4-b265cdd9f12f
# 21  c824ed28-cf51-4bc2-8d16-05b8145b7139
# 22  b100ba1e-61d0-43a2-8aa0-de25c082194e
# 23  909bfde1-6aad-4c0b-9528-faf29f9c0629
# 24  6015befa-dad7-4218-aa3a-7e444d944a2b
# 25  3543f1a7-7a1d-442c-9ec1-8a189a321fd5
# 26  11a300c4-c910-41d3-8edd-6accf9a33738
# 27  55fd7ceb-b9dd-43dc-a4e3-c35590fd6c65
# 28  a6c26dc0-2bd5-438f-9769-2b18bd0ccd14
# 29  c545a84e-f599-427b-bda0-586cb5fab797
# 30  2b1ff236-f209-4d89-baba-95ba1b2a8ef4
# 31  cdc4c331-5b63-4f73-b088-482da24fe93c
# 32  cc4bf6e8-661a-4fd6-8e02-9e4a8f79c746
# 33  41b82df9-a2eb-4181-829a-6c19a1bc3bae
# 34  4f2fcf77-2d42-4a46-a705-b8f1ad9b3332
# 35  6c99a0b7-3ffb-401c-8e2c-4ace1973d6e4
# 36  e2f6c1ce-2eb4-4bb7-bf4b-971858a71470
# 37  f495152a-3536-4e19-b8f9-579dce483a56
# 38  1b227563-2cce-4d38-9eba-fa2a856658a8
# 39  c3d4e35b-42b2-4c53-a188-508998fd100c
# 40  9e115d54-dbeb-4b19-a5bb-da1eb0f2bc1f
# 41  b53d6f3c-e140-4d81-a864-b678cf0b88fc
# 42  6594e5f1-2b63-4cf3-9c06-9d08141ded99
# 43  dd8cc32c-c314-440a-bbbf-67af87bba139
# 44  378279e0-dd2f-4bcc-945e-46cad8dfb43e
# 45  bbf657c8-74c8-4a55-a77b-ef8da15655ba
# 46  57ce98d0-13f1-44ad-9a11-394c11455d46
# 47  5179cc54-f23e-4b15-9527-296d2b37482c
# 48  ea9cf6e1-a3f0-4b05-abf2-259a4a889491
# 49  277c632b-ef8e-488f-a93b-58e23bfc2e78
# 50  4d0ce105-cd32-4e94-bb16-08899ef0b670
# 51  5dba1ec6-df5c-439a-bc43-8ae416aedb95
# 52  85a2890a-ad15-4e3f-a6a2-bc10ea5841a3
# 53  fa793696-ec04-4ecc-b523-2ffb2306159e
# 54  9ee5ddb9-439c-40f4-a466-b84f86608a83
# 55  4973f404-60c5-44dc-8f8b-39fe87f98019
# 56  7a7a8bb2-8524-45b4-95e4-1921de20c217
#
#                                                                                                                              resources  \
# 0                                                                                                                                 None
# 1                                                                                                                                 None
# 2                                         [{arn=arn:aws:s3:::test-s3-cloudtrail-bucket, accountid=910003606845, type=AWS::S3::Bucket}]
# 3                                                    [{arn=arn:aws:s3:::tfc-ml-ai-2020, accountid=910003606845, type=AWS::S3::Bucket}]
# 4                           [{arn=arn:aws:s3:::sagemaker-studio-us-west-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 5                                                     [{arn=arn:aws:s3:::test-20200505, accountid=910003606845, type=AWS::S3::Bucket}]
# 6                               [{arn=arn:aws:s3:::test-cost-usage-billing-report-2021, accountid=910003606845, type=AWS::S3::Bucket}]
# 7                      [{arn=arn:aws:s3:::sagemaker-studio-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 8                           [{arn=arn:aws:s3:::sagemaker-studio-us-east-1-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 9                         [{arn=arn:aws:s3:::sagemaker-studio-910003606845-ng9u93sj4tf, accountid=910003606845, type=AWS::S3::Bucket}]
# 10                   [{arn=arn:aws:s3:::sagemaker-notebook-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 11                        [{arn=arn:aws:s3:::sagemaker-studio-910003606845-mbuglbudgrc, accountid=910003606845, type=AWS::S3::Bucket}]
# 12                            [{arn=arn:aws:s3:::sagemaker-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 13                               [{arn=arn:aws:s3:::s3-lens-dashboard-export-data-2021, accountid=910003606845, type=AWS::S3::Bucket}]
# 14                                       [{arn=arn:aws:s3:::s3-health-stack-106-bucket, accountid=910003606845, type=AWS::S3::Bucket}]
# 15  [{arn=arn:aws:s3:::reinforce2021-tdr254-clo-athenaqueryresultsbucket-1inggpjk2pxo7, accountid=910003606845, type=AWS::S3::Bucket}]
# 16                 [{arn=arn:aws:s3:::reinforce2021-tdr254-910003606845-us-east-1-data, accountid=910003606845, type=AWS::S3::Bucket}]
# 17                                                [{arn=arn:aws:s3:::pyky2-report-repo, accountid=910003606845, type=AWS::S3::Bucket}]
# 18                        [{arn=arn:aws:s3:::reinforce2021-cloudtrail-jerchen-20211014, accountid=910003606845, type=AWS::S3::Bucket}]
# 19         [{arn=arn:aws:s3:::photoalbumsf3dd7d27073c40d4b032fa95d3f04c7e104750-master, accountid=910003606845, type=AWS::S3::Bucket}]
# 20                  [{arn=arn:aws:s3:::photoalbums-20201118111318-hostingbucket-master, accountid=910003606845, type=AWS::S3::Bucket}]
# 21                   [{arn=arn:aws:s3:::openaq-forecasting-910003606845-ap-southeast-2, accountid=910003606845, type=AWS::S3::Bucket}]
# 22                                          [{arn=arn:aws:s3:::my-test-bucket-20191011, accountid=910003606845, type=AWS::S3::Bucket}]
# 23                            [{arn=arn:aws:s3:::my-athena-query-result-s3-bucket-2021, accountid=910003606845, type=AWS::S3::Bucket}]
# 24                   [{arn=arn:aws:s3:::mlops-aqf-artifact-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 25                             [{arn=arn:aws:s3:::jc-lambda-twitter-python-test-bucket, accountid=910003606845, type=AWS::S3::Bucket}]
# 26                                         [{arn=arn:aws:s3:::lf-workshop-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 27                                        [{arn=arn:aws:s3:::lf-data-lake-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 28                     [{arn=arn:aws:s3:::elasticbeanstalk-ap-southeast-2-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 29                                          [{arn=arn:aws:s3:::heath-api-lab-s3-bucket, accountid=910003606845, type=AWS::S3::Bucket}]
# 30                     [{arn=arn:aws:s3:::do-not-delete-gatedgarden-audit-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 31                                             [{arn=arn:aws:s3:::connect-b8df6a1f839a, accountid=910003606845, type=AWS::S3::Bucket}]
# 32                                       [{arn=arn:aws:s3:::config-bucket-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 33                                             [{arn=arn:aws:s3:::connect-08294e685d8f, accountid=910003606845, type=AWS::S3::Bucket}]
# 34                              [{arn=arn:aws:s3:::cf-templates-d2673lchlwob-us-west-2, accountid=910003606845, type=AWS::S3::Bucket}]
# 35  [{arn=arn:aws:s3:::cloudtrail-awslogs-910003606845-k9lbmss8-isengard-do-not-delete, accountid=910003606845, type=AWS::S3::Bucket}]
# 36                              [{arn=arn:aws:s3:::cf-templates-d2673lchlwob-us-west-1, accountid=910003606845, type=AWS::S3::Bucket}]
# 37                              [{arn=arn:aws:s3:::cf-templates-d2673lchlwob-us-east-2, accountid=910003606845, type=AWS::S3::Bucket}]
# 38                              [{arn=arn:aws:s3:::cf-templates-d2673lchlwob-us-east-1, accountid=910003606845, type=AWS::S3::Bucket}]
# 39                         [{arn=arn:aws:s3:::cf-templates-d2673lchlwob-ap-southeast-2, accountid=910003606845, type=AWS::S3::Bucket}]
# 40                            [{arn=arn:aws:s3:::aws-org-cloudtrail-s3-bucket-20200203, accountid=910003606845, type=AWS::S3::Bucket}]
# 41                                                 [{arn=arn:aws:s3:::aws-jerchen-logs, accountid=910003606845, type=AWS::S3::Bucket}]
# 42                                  [{arn=arn:aws:s3:::aws-config-data-bucket-20210414, accountid=910003606845, type=AWS::S3::Bucket}]
# 43                           [{arn=arn:aws:s3:::aws-glue-assets-910003606845-us-east-1, accountid=910003606845, type=AWS::S3::Bucket}]
# 44               [{arn=arn:aws:s3:::aws-deepracer-92b4750e-72a6-4d0c-8a65-478c0597266c, accountid=910003606845, type=AWS::S3::Bucket}]
# 45                            [{arn=arn:aws:s3:::app-cost-profiler-testreport-20210520, accountid=910003606845, type=AWS::S3::Bucket}]
# 46                                  [{arn=arn:aws:s3:::app-cost-profiler-test-20210520, accountid=910003606845, type=AWS::S3::Bucket}]
# 47                     [{arn=arn:aws:s3:::amplify-photoalbums-master-104750-deployment, accountid=910003606845, type=AWS::S3::Bucket}]
# 48                                       [{arn=arn:aws:s3:::acp-us-east-1-910003606845, accountid=910003606845, type=AWS::S3::Bucket}]
# 49                   [{arn=arn:aws:s3:::910003606845-fraud-detector-lab-ap-southeast-2, accountid=910003606845, type=AWS::S3::Bucket}]
# 50                         [{arn=arn:aws:s3:::amplify-lexchatbot-dev-161955-deployment, accountid=910003606845, type=AWS::S3::Bucket}]
# 51                                                                                                                                None
# 52                                                                                                                                None
# 53                                                                                                                                None
# 54                                                                                                                                None
# 55                                                                                                                                None
# 56                                                                                                                                None
#
#      eventtype  apiversion readonly recipientaccountid serviceeventdetails  \
# 0   AwsApiCall        None    false       910003606845                None
# 1   AwsApiCall        None    false       910003606845                None
# 2   AwsApiCall        None    false       910003606845                None
# 3   AwsApiCall        None    false       910003606845                None
# 4   AwsApiCall        None    false       910003606845                None
# 5   AwsApiCall        None    false       910003606845                None
# 6   AwsApiCall        None    false       910003606845                None
# 7   AwsApiCall        None    false       910003606845                None
# 8   AwsApiCall        None    false       910003606845                None
# 9   AwsApiCall        None    false       910003606845                None
# 10  AwsApiCall        None    false       910003606845                None
# 11  AwsApiCall        None    false       910003606845                None
# 12  AwsApiCall        None    false       910003606845                None
# 13  AwsApiCall        None    false       910003606845                None
# 14  AwsApiCall        None    false       910003606845                None
# 15  AwsApiCall        None    false       910003606845                None
# 16  AwsApiCall        None    false       910003606845                None
# 17  AwsApiCall        None    false       910003606845                None
# 18  AwsApiCall        None    false       910003606845                None
# 19  AwsApiCall        None    false       910003606845                None
# 20  AwsApiCall        None    false       910003606845                None
# 21  AwsApiCall        None    false       910003606845                None
# 22  AwsApiCall        None    false       910003606845                None
# 23  AwsApiCall        None    false       910003606845                None
# 24  AwsApiCall        None    false       910003606845                None
# 25  AwsApiCall        None    false       910003606845                None
# 26  AwsApiCall        None    false       910003606845                None
# 27  AwsApiCall        None    false       910003606845                None
# 28  AwsApiCall        None    false       910003606845                None
# 29  AwsApiCall        None    false       910003606845                None
# 30  AwsApiCall        None    false       910003606845                None
# 31  AwsApiCall        None    false       910003606845                None
# 32  AwsApiCall        None    false       910003606845                None
# 33  AwsApiCall        None    false       910003606845                None
# 34  AwsApiCall        None    false       910003606845                None
# 35  AwsApiCall        None    false       910003606845                None
# 36  AwsApiCall        None    false       910003606845                None
# 37  AwsApiCall        None    false       910003606845                None
# 38  AwsApiCall        None    false       910003606845                None
# 39  AwsApiCall        None    false       910003606845                None
# 40  AwsApiCall        None    false       910003606845                None
# 41  AwsApiCall        None    false       910003606845                None
# 42  AwsApiCall        None    false       910003606845                None
# 43  AwsApiCall        None    false       910003606845                None
# 44  AwsApiCall        None    false       910003606845                None
# 45  AwsApiCall        None    false       910003606845                None
# 46  AwsApiCall        None    false       910003606845                None
# 47  AwsApiCall        None    false       910003606845                None
# 48  AwsApiCall        None    false       910003606845                None
# 49  AwsApiCall        None    false       910003606845                None
# 50  AwsApiCall        None    false       910003606845                None
# 51  AwsApiCall        None     true       910003606845                None
# 52  AwsApiCall        None     true       910003606845                None
# 53  AwsApiCall        None     true       910003606845                None
# 54  AwsApiCall  2012-08-10     true       910003606845                None
# 55  AwsApiCall        None     true       910003606845                None
# 56  AwsApiCall        None     true       910003606845                None
#
#    sharedeventid vpcendpointid
# 0           None          None
# 1           None          None
# 2           None          None
# 3           None          None
# 4           None          None
# 5           None          None
# 6           None          None
# 7           None          None
# 8           None          None
# 9           None          None
# 10          None          None
# 11          None          None
# 12          None          None
# 13          None          None
# 14          None          None
# 15          None          None
# 16          None          None
# 17          None          None
# 18          None          None
# 19          None          None
# 20          None          None
# 21          None          None
# 22          None          None
# 23          None          None
# 24          None          None
# 25          None          None
# 26          None          None
# 27          None          None
# 28          None          None
# 29          None          None
# 30          None          None
# 31          None          None
# 32          None          None
# 33          None          None
# 34          None          None
# 35          None          None
# 36          None          None
# 37          None          None
# 38          None          None
# 39          None          None
# 40          None          None
# 41          None          None
# 42          None          None
# 43          None          None
# 44          None          None
# 45          None          None
# 46          None          None
# 47          None          None
# 48          None          None
# 49          None          None
# 50          None          None
# 51          None          None
# 52          None          None
# 53          None          None
# 54          None          None
# 55          None          None
# 56          None          None
#
# [57 rows x 23 columns]

# %% [markdown]
# ### Step 3 - Bring it all together
# Bring together the previous queries to create a single query showing the event name, AWS service, and AWS region where requests were being made to by the compromised IAM entity.

# %%
query = """
select eventName, count(*) as total, eventSource, awsRegion
from cloudtrail_logs
where userIdentity.arn='arn:aws:iam::910003606845:user/compromized_account'
and eventTime >= '2021-10-13T11:45:00Z'
and eventTime < '2021-10-15T11:45:30Z'
group by eventName, eventSource, awsRegion
order by total desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#             eventName  total               eventSource       awsRegion
# 0        DeleteBucket     24          s3.amazonaws.com       us-east-1
# 1        DeleteBucket     14          s3.amazonaws.com  ap-southeast-2
# 2        DeleteBucket      5          s3.amazonaws.com       us-west-2
# 3        DeleteBucket      4          s3.amazonaws.com  ap-southeast-1
# 4          ListTables      1    dynamodb.amazonaws.com       us-east-1
# 5         ListBuckets      1          s3.amazonaws.com       us-east-1
# 6   DescribeInstances      1         ec2.amazonaws.com       us-east-1
# 7          ListTrails      1  cloudtrail.amazonaws.com       us-east-1
# 8        DeleteBucket      1          s3.amazonaws.com       us-east-2
# 9        RunInstances      1         ec2.amazonaws.com       us-east-1
# 10      ListDetectors      1   guardduty.amazonaws.com       us-east-1
# 11         CreateUser      1         iam.amazonaws.com       us-east-1
# 12          ListUsers      1         iam.amazonaws.com       us-east-1
# 13       DeleteBucket      1          s3.amazonaws.com       us-west-1

# %% [markdown]
# ### Step 4 - Containment
# Now that you have identified the potential IAM entity which has been compromised you need to perform containment activities. The first of these will be to find out what the Access Key ID is being used by the account.

# %%
query = """
select eventName, count(*) as total, eventSource, awsRegion
from cloudtrail_logs
where userIdentity.arn='arn:aws:iam::910003606845:user/compromized_account'
group by eventName, eventSource, awsRegion
order by total desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#             eventName  total               eventSource       awsRegion
# 0        DeleteBucket     24          s3.amazonaws.com       us-east-1
# 1        DeleteBucket     14          s3.amazonaws.com  ap-southeast-2
# 2        DeleteBucket      5          s3.amazonaws.com       us-west-2
# 3        DeleteBucket      4          s3.amazonaws.com  ap-southeast-1
# 4          ListTrails      1  cloudtrail.amazonaws.com       us-east-1
# 5   DescribeInstances      1         ec2.amazonaws.com       us-east-1
# 6        DeleteBucket      1          s3.amazonaws.com       us-east-2
# 7          ListTables      1    dynamodb.amazonaws.com       us-east-1
# 8           ListUsers      1         iam.amazonaws.com       us-east-1
# 9        DeleteBucket      1          s3.amazonaws.com       us-west-1
# 10      ListDetectors      1   guardduty.amazonaws.com       us-east-1
# 11       RunInstances      1         ec2.amazonaws.com       us-east-1
# 12         CreateUser      1         iam.amazonaws.com       us-east-1
# 13        ListBuckets      1          s3.amazonaws.com       us-east-1

# %%
query = """
select useridentity.accesskeyid, count(*) as total
from cloudtrail_logs
where userIdentity.arn='arn:aws:iam::910003606845:user/compromized_account'
group by useridentity.accesskeyid
order by total desc;
"""
results = pd.read_sql(query, conn)
results
# Out:
#             accesskeyid  total
# 0  AKIA5HYDRCU6VSTSXB5G     57

# %%
access_key_to_deactivate='AKIA5HYDRCU6VSTSXB5G'
username='jerchen'
iam = boto3.resource('iam', region_name=region)
access_key = iam.AccessKey(username,access_key_to_deactivate)
response_status = access_key.deactivate()
status_code = response_status['ResponseMetadata']['HTTPStatusCode']
if status_code == 200:
    print('Key Disabled Successfully')
else:
    print('Key deactivation failed')
# Out:
# ---------------------------------------------------------------------------
# NoSuchEntityException                     Traceback (most recent call last)
# <ipython-input-18-17c737f3a803> in <module>
#       3 iam = boto3.resource('iam', region_name=region)
#       4 access_key = iam.AccessKey(username,access_key_to_deactivate)
# ----> 5 response_status = access_key.deactivate()
#       6 status_code = response_status['ResponseMetadata']['HTTPStatusCode']
#       7 if status_code == 200:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/resources/factory.py in do_action(self, *args, **kwargs)
#     518             # instance via ``self``.
#     519             def do_action(self, *args, **kwargs):
# --> 520                 response = action(self, *args, **kwargs)
#     521
#     522                 if hasattr(self, 'load'):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/resources/action.py in __call__(self, parent, *args, **kwargs)
#      81                      operation_name, params)
#      82
# ---> 83         response = getattr(parent.meta.client, operation_name)(*args, **params)
#      84
#      85         logger.debug('Response: %r', response)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     384                     "%s() only accepts keyword arguments." % py_operation_name)
#     385             # The "self" in this scope is referring to the BaseClient.
# --> 386             return self._make_api_call(operation_name, kwargs)
#     387
#     388         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     703             error_code = parsed_response.get("Error", {}).get("Code")
#     704             error_class = self.exceptions.from_code(error_code)
# --> 705             raise error_class(parsed_response, operation_name)
#     706         else:
#     707             return parsed_response
#
# NoSuchEntityException: An error occurred (NoSuchEntity) when calling the UpdateAccessKey operation: The Access Key with id AKIA5HYDRCU6VSTSXB5G cannot be found.

# %%
username='USERNAME'
iam = boto3.client('iam', region_name=region)
response = iam.put_user_policy(UserName=username,PolicyName='Block',PolicyDocument='{"Version":"2012-10-17","Statement":{"Effect":"Deny","Action":"*","Resource":"*"}}')
status_code = response['ResponseMetadata']['HTTPStatusCode']
if status_code == 200:
    print('Policy attached successfully')
else:
    print('Policy attachment failed')

# %% [markdown]
# ## Investigation 2
#
# In the second investigation you have been made aware of a potential security incident in your AWS account, some suspicious behaviour has been identified by an engineering team due them identifying an unknown EC2 instance during a scheduled patching event. At this time they can’t provide you any more details so you’ll need to do your own investigations!

# %% [markdown]
# ### Step 1 - Discovery
# As you know there are some suspicious EC2 instance(s) the first step is to try to identify if any instance(s) are performing suspicious activities. Sometimes this would be discovery actions, such as listing S3 buckets to try and enumerate resources in your environment, this isn’t a normal activity that you’d expect EC2 instances to be performing.

# %%
query = """
select useridentity.principalid,eventsource,eventname,count(*) as total
from cloudtrail_logs
where useridentity.principalid like '%:i-%'
and eventsource = 's3.amazonaws.com'
and eventname = 'ListBuckets'
group by useridentity.principalid,eventsource,eventname
order by total desc;
"""
results = pd.read_sql(query, conn)
results

# %% [markdown]
# ### Step 2 - Initial investigation
# Now that you have identified the potential IAM entity which has been compromised, you should do further investigations to identify what the entity has been attemping to do.

# %%
query = """

"""
results = pd.read_sql(query, conn)
results

# %% [markdown]
# ### Step 3 - Bring it all together

# %%
query = """

"""
results = pd.read_sql(query, conn)
results

# %% [markdown]
# ### Step 4 - Containment
# To secure the EC2 instance for further investigation, you should place it into a new, restricted security group (rather than changing the exisiting security group as this won’t terminate active sessions), and snapshot the EBS volume for future investigation.

# %%
import time
instance_id='<INSTANCE_ID>'
ec2=boto3.resource('ec2')
instance=ec2.Instance(instance_id)
vpc_id=instance.vpc_id
security_group=instance.security_groups[0]['GroupId']
ec2_client=boto3.client('ec2')
response=ec2_client.create_security_group(
    GroupName='Restricted_Group',
    Description='Restricts_access',
    VpcId=vpc_id
)
restricted_sg=ec2.SecurityGroup(response['GroupId'])
response=restricted_sg.revoke_egress(
    IpPermissions=restricted_sg.ip_permissions_egress
)
response=instance.modify_attribute(Groups=[restricted_sg.id])
ebs_vol=instance.block_device_mappings[0]['Ebs']['VolumeId']
response=ec2.create_snapshot(VolumeId=ebs_vol)
time.sleep(30)
instance.terminate()
